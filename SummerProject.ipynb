# %%
import numpy as np
import matplotlib.pyplot as plt
import math # just in case

# the parameters:
# {s, r, g }= {-0.01, 0.1, 0.001}
# {CS0, CR0} = {0.9,0.1}

CS0 = 0.9  #sensitive cells
CR0 = 0.1  #resistant cells
s = -0.01
r =   0.1  #use the numbers from the paper
g = 0.001


#independent variable t (time in days for 30 days):
t = np.arange(0,30,1)

# set the CS, CR, and CP
CS = np.zeros(len(t))
CR = np.zeros(len(t))
CP = np.zeros(len(t))

#initial values:
CS[0]= CS0
CR[0]= CR0
CP[0]= CS0 + CR0

for i in range(1,len(t)+1):
    CS[i]= CS0*np.exp(-(g-s)*t[i])
    CR[i]= (CS0 * (g*(np.exp(r*t[i])-np.exp(-(g-s)*t[i])))/(g+r-s)) + (CR0*np.exp(r*t[i]))
    #CP[i+1]=
    
# plot:
plt.title("Plots")
plt.xlabel("time")
plt.ylabel("cell population")
plt.plot(t,CS, \
        label = 'sensitive')
plt.plot(t,CR, \
        label = 'resistant')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-4e0ff2287c42> in <module>
#      28
#      29 for i in range(1,len(t)):
# ---> 30     CS[i]= CS0*np.exp(-(g-s)*t)
#      31     CR[i]= (CS0 * (g*(np.exp(r*t)-np.exp(-(g-s)*t)))/(g+r-s)) + (CR0*np.exp(r*t))
#      32     #CP[i+1]=
#
# ValueError: setting an array element with a sequence.

# %%
import numpy as np
import matplotlib.pyplot as plt
import math # just in case

# the parameters:
# {s, r, g }= {-0.01, 0.1, 0.001}
# {CS0, CR0} = {0.9,0.1}

CS0 = 0.9  #sensitive cells
CR0 = 0.1  #resistant cells
s = -0.01
r =   0.1  #use the numbers from the paper
g = 0.001


#independent variable t (time in days for 30 days):
t = np.arange(0,30,1)

# set the CS, CR, and CP
CS = np.zeros(len(t))
CR = np.zeros(len(t))
CP = np.zeros(len(t))

#initial values:
CS[0]= CS0
CR[0]= CR0
CP[0]= CS0 + CR0

for i in range(1,len(t)+1):
    CS[i]= CS0*np.exp(-(g-s)*t[i])
    CR[i]= (CS0 * (g*(np.exp(r*t[i])-np.exp(-(g-s)*t[i])))/(g+r-s)) + (CR0*np.exp(r*t[i]))
    #CP[i+1]=
    
# plot:
plt.title("Plots")
plt.xlabel("time")
plt.ylabel("cell population")
plt.plot(t,CS, \
        label = 'sensitive')
plt.plot(t,CR, \
        label = 'resistant')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-fc9f56e43914> in <module>
#      28
#      29 for i in range(1,len(t)+1):
# ---> 30     CS[i]= CS0*np.exp(-(g-s)*t[i])
#      31     CR[i]= (CS0 * (g*(np.exp(r*t[i])-np.exp(-(g-s)*t[i])))/(g+r-s)) + (CR0*np.exp(r*t[i]))
#      32     #CP[i+1]=
#
# IndexError: index 30 is out of bounds for axis 0 with size 30

# %%
import numpy as np
import matplotlib.pyplot as plt
import math # just in case

# the parameters:
# {s, r, g }= {-0.01, 0.1, 0.001}
# {CS0, CR0} = {0.9,0.1}

CS0 = 0.9  #sensitive cells
CR0 = 0.1  #resistant cells
s = -0.01
r =   0.1  #use the numbers from the paper
g = 0.001


#independent variable t (time in days for 30 days):
t = np.arange(0,30,1)

# set the CS, CR, and CP
CS = np.zeros(len(t))
CR = np.zeros(len(t))
CP = np.zeros(len(t))

#initial values:
CS[0]= CS0
CR[0]= CR0
CP[0]= CS0 + CR0

for i in range(1,len(t)):
    CS[i]= CS0*np.exp(-(g-s)*t[i])
    CR[i]= (CS0 * (g*(np.exp(r*t[i])-np.exp(-(g-s)*t[i])))/(g+r-s)) + (CR0*np.exp(r*t[i]))
    #CP[i+1]=
    
# plot:
plt.title("Plots")
plt.xlabel("time")
plt.ylabel("cell population")
plt.plot(t,CS, \
        label = 'sensitive')
plt.plot(t,CR, \
        label = 'resistant')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math # just in case

# the parameters:
# {s, r, g }= {-0.01, 0.1, 0.001}
# {CS0, CR0} = {0.9,0.1}

CS0 = 0.9  #sensitive cells
CR0 = 0.1  #resistant cells
s = -0.01
r =   0.1  #use the numbers from the paper
g = 0.001


#independent variable t (time in days for 30 days):
t = np.arange(0,31,1)

# set the CS, CR, and CP
CS = np.zeros(len(t))
CR = np.zeros(len(t))
CP = np.zeros(len(t))

#initial values:
CS[0]= CS0
CR[0]= CR0
CP[0]= CS0 + CR0

for i in range(1,len(t)+1):
    CS[i]= CS0*np.exp(-(g-s)*t[i])
    CR[i]= (CS0 * (g*(np.exp(r*t[i])-np.exp(-(g-s)*t[i])))/(g+r-s)) + (CR0*np.exp(r*t[i]))
    #CP[i+1]=
    
# plot:
plt.title("Plots")
plt.xlabel("time")
plt.ylabel("cell population")
plt.plot(t,CS, \
        label = 'sensitive')
plt.plot(t,CR, \
        label = 'resistant')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-0419c8ca4bd3> in <module>
#      28
#      29 for i in range(1,len(t)+1):
# ---> 30     CS[i]= CS0*np.exp(-(g-s)*t[i])
#      31     CR[i]= (CS0 * (g*(np.exp(r*t[i])-np.exp(-(g-s)*t[i])))/(g+r-s)) + (CR0*np.exp(r*t[i]))
#      32     #CP[i+1]=
#
# IndexError: index 31 is out of bounds for axis 0 with size 31

# %%
import numpy as np
import matplotlib.pyplot as plt
import math # just in case

# the parameters:
# {s, r, g }= {-0.01, 0.1, 0.001}
# {CS0, CR0} = {0.9,0.1}

CS0 = 0.9  #sensitive cells
CR0 = 0.1  #resistant cells
s = -0.01
r =   0.1  #use the numbers from the paper
g = 0.001


#independent variable t (time in days for 30 days):
t = np.arange(0,30,1)

# set the CS, CR, and CP
CS = np.zeros(len(t))
CR = np.zeros(len(t))
CP = np.zeros(len(t))

#initial values:
CS[0]= CS0
CR[0]= CR0
CP[0]= CS0 + CR0

for i in range(1,len(t)):
    CS[i]= CS0*np.exp(-(g-s)*t[i])
    CR[i]= (CS0 * (g*(np.exp(r*t[i])-np.exp(-(g-s)*t[i])))/(g+r-s)) + (CR0*np.exp(r*t[i]))
    #CP[i+1]=
    
# plot:
plt.title("Plots")
plt.xlabel("time")
plt.ylabel("cell population")
plt.plot(t,CS, \
        label = 'sensitive')
plt.plot(t,CR, \
        label = 'resistant')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math # just in case

# the parameters:
# {s, r, g }= {-0.01, 0.1, 0.001}
# {CS0, CR0} = {0.9,0.1}

CS0 = 0.9  #sensitive cells
CR0 = 0.1  #resistant cells
s = -0.01
r =   0.1  #use the numbers from the paper
g = 0.001


#independent variable t (time in days for 30 days):
t = np.arange(0,30,1)

# set the CS, CR, and CP
CS = np.zeros(len(t))
CR = np.zeros(len(t))
CP = np.zeros(len(t))

#initial values:
CS[0]= CS0
CR[0]= CR0
CP[0]= CS0 + CR0

for i in range(1,len(t)):
    CS[i]= CS0*np.exp(-(g-s)*t[i])
    CR[i]= (CS0 * (g*(np.exp(r*t[i])-np.exp(-(g-s)*t[i])))/(g+r-s)) + (CR0*np.exp(r*t[i]))
    CP[i]= CS[i]+ CR[i]
    
# plot:
plt.title("Plots")
plt.xlabel("time")
plt.ylabel("cell population")
plt.plot(t,CS, \
        label = 'sensitive')
plt.plot(t,CR, \
        label = 'resistant')
plt.plot(t, CP, \
        label = 'total')
plt.legend()
plt.show()

# %%
# version 2 with changed paramters {s, r, g}= {-0.09, 0.08, 0.001}

import numpy as np
import matplotlib.pyplot as plt
import math # just in case

# the parameters:
#{s, r, g}= {-0.09, 0.08, 0.001}
#older version: {s, r, g }= {-0.01, 0.1, 0.001}
# {CS0, CR0} = {0.9,0.1}

CS0 = 0.9  #sensitive cells
CR0 = 0.1  #resistant cells
s = -0.09
r =   0.08  #use the numbers from the paper
g = 0.001


#independent variable t (time in days for 30 days):
t = np.arange(0,30,1)

# set the CS, CR, and CP
CS = np.zeros(len(t))
CR = np.zeros(len(t))
CP = np.zeros(len(t))

#initial values:
CS[0]= CS0
CR[0]= CR0
CP[0]= CS0 + CR0

for i in range(1,len(t)):
    CS[i]= CS0*np.exp(-(g-s)*t[i])
    CR[i]= (CS0 * (g*(np.exp(r*t[i])-np.exp(-(g-s)*t[i])))/(g+r-s)) + (CR0*np.exp(r*t[i]))
    CP[i]= CS[i]+ CR[i]
    
# plot:
plt.title("Plots")
plt.xlabel("time")
plt.ylabel("cell population")
plt.plot(t,CS, \
        label = 'sensitive')
plt.plot(t,CR, \
        label = 'resistant')
plt.plot(t, CP, \
        label = 'total')
plt.legend()
plt.show()
